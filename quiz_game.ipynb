# %%
questions = ("How many elements are in periodic table?: ",
            "Which animal lays the largest eggs?: ",
            "Waht is the most abundant gas in Earth's atmosphere?: ",
            "How many bones are in the human body?: ",
            "Which planet in the solar system is the hottest?: ")

options = (("A. 116","B. 117","C. 118", "D. 119"),
           ("A. Whale","B. Crocodile","C. Elephant", "D. Ostrich"),
           ("A. Nitrogen","B. Oxygen","C. Hydrogen", "D. Calcium"),
           ("A. 200","B. 202","C. 205", "D. 201"),
           ("A. Mars","B. Earth","C. Sarturn", "D. Mercury"))

aswers = ("C", "D", "A", "A", "D")
guesses = []
score = 0
question_num = 0


for question in questions:
    print("-" * 20)
    print(question)
    for option in options[question_num]:
        print(option)
    guess = input("Enter (A, B, C, D): ").upper()
    guesses.append(guesses)
    if guess == aswers[question_num]:
        print("Correct")
    else:
        print("Incorrect")
        print(f"Right aswers is {aswers[question_num]}")
    question_num += 1
# Out:
# --------------------
# How many elements are in periodic table?:
# A. 116
# B. 117
# C. 118
# D. 119
# Incorrect
# Right aswers is C
# --------------------
# Which animal lays the largest eggs?:
# A. Whale
# B. Crocodile
# C. Elephant
# D. Ostrich
# Correct
# --------------------
# Waht is the most abundant gas in Earth's atmosphere?:
# A. Nitrogen
# B. Oxygen
# C. Hydrogen
# D. Calcium
# Correct
# --------------------
# How many bones are in the human body?:
# A. 200
# B. 202
# C. 205
# D. 201
# Correct
# --------------------
# Which planet in the solar system is the hottest?:
# A. Mars
# B. Earth
# C. Sarturn
# D. Mercury
# Incorrect
# Right aswers is D

# %%
questions = ("How many elements are in periodic table?: ",
            "Which animal lays the largest eggs?: ",
            "Waht is the most abundant gas in Earth's atmosphere?: ",
            "How many bones are in the human body?: ",
            "Which planet in the solar system is the hottest?: ")

options = (("A. 116","B. 117","C. 118", "D. 119"),
           ("A. Whale","B. Crocodile","C. Elephant", "D. Ostrich"),
           ("A. Nitrogen","B. Oxygen","C. Hydrogen", "D. Calcium"),
           ("A. 200","B. 202","C. 205", "D. 201"),
           ("A. Mars","B. Earth","C. Sarturn", "D. Mercury"))

answers = ("C", "D", "A", "A", "D")
guesses = []
score = 0
question_num = 0


for question in questions:
    print("-" * 20)
    print(question)

    for option in options[question_num]:
        print(option)

    guess = input("Enter de option (A, B, C, D): ").upper()

    if guess == answers[question_num]:
        print("CORRECT")
    
    else:
        print("INCORRECT")
        print(f"The right answer is {answers[question_num]}")

    question_num += 1
# Out:
# --------------------
# How many elements are in periodic table?:
# A. 116
# B. 117
# C. 118
# D. 119
# CORRECT
# --------------------
# Which animal lays the largest eggs?:
# A. Whale
# B. Crocodile
# C. Elephant
# D. Ostrich
# CORRECT
# --------------------
# Waht is the most abundant gas in Earth's atmosphere?:
# A. Nitrogen
# B. Oxygen
# C. Hydrogen
# D. Calcium
# CORRECT
# --------------------
# How many bones are in the human body?:
# A. 200
# B. 202
# C. 205
# D. 201
# CORRECT
# --------------------
# Which planet in the solar system is the hottest?:
# A. Mars
# B. Earth
# C. Sarturn
# D. Mercury
# CORRECT
